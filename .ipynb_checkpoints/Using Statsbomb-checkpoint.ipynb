# %% [markdown]
# ## Using StatsBomb
# This will provide an initial overview of the StatsBomb match data available freely for hobbies soccer analyst like myself.

# %%
# importing SBopen from mplsoccer library to open the match data
# mplsoccer is leveraging a statsbomb library dependancy for this feature
from mplsoccer import Sbopen

# Instantiate a data parser
parser = Sbopen()

# competitions, seasons and match data available
df_comps = parser.competition()

# %%
df_comps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   competition_id             43 non-null     int64
#  1   season_id                  43 non-null     int64
#  2   country_name               43 non-null     object
#  3   competition_name           43 non-null     object
#  4   competition_gender         43 non-null     object
#  5   competition_youth          43 non-null     bool
#  6   competition_international  43 non-null     bool
#  7   season_name                43 non-null     object
#  8   match_updated              43 non-null     object
#  9   match_updated_360          42 non-null     object
#  10  match_available_360        4 non-null      object
#  11  match_available            43 non-null     object
# dtypes: bool(2), int64(2), object(8)
# memory usage: 3.6+ KB

# %%
# Using chaining methods from Matt Harrison
(df_comps
 .competition_name
 .unique()
)
# Out:
# array(['Champions League', "FA Women's Super League", 'FIFA World Cup',
#        'Indian Super league', 'La Liga', 'NWSL', 'Premier League',
#        'UEFA Euro', "UEFA Women's Euro", "Women's World Cup"],
#       dtype=object)

# %% [markdown]
# ###  Competitions available
# There are quite a few competitions available.  The EPL and La Liga are the most immediately intersting, especially to compare over styles of play between the two groups.  I would be curious to know which of the two leauges plays more fluidly, with more possession, less turnovers, and more successfully executed sequences.  Some ideas for aggregated comparison:
# - Average passes per game in the same season
# - Average shots per game
# - Average fouls, restarts, etc.

# %%
(df_comps
 .query('competition_name.isin(["Premier League","La Liga"])')
)
# Out:
#     competition_id  season_id country_name competition_name
# 21              11         90        Spain          La Liga  \
# 22              11         42        Spain          La Liga
# 23              11          4        Spain          La Liga
# 24              11          1        Spain          La Liga
# 25              11          2        Spain          La Liga
# 26              11         27        Spain          La Liga
# 27              11         26        Spain          La Liga
# 28              11         25        Spain          La Liga
# 29              11         24        Spain          La Liga
# 30              11         23        Spain          La Liga
# 31              11         22        Spain          La Liga
# 32              11         21        Spain          La Liga
# 33              11         41        Spain          La Liga
# 34              11         40        Spain          La Liga
# 35              11         39        Spain          La Liga
# 36              11         38        Spain          La Liga
# 37              11         37        Spain          La Liga
# 39               2         44      England   Premier League
#
#    competition_gender  competition_youth  competition_international
# 21               male              False                      False  \
# 22               male              False                      False
# 23               male              False                      False
# 24               male              False                      False
# 25               male              False                      False
# 26               male              False                      False
# 27               male              False                      False
# 28               male              False                      False
# 29               male              False                      False
# 30               male              False                      False
# 31               male              False                      False
# 32               male              False                      False
# 33               male              False                      False
# 34               male              False                      False
# 35               male              False                      False
# 36               male              False                      False
# 37               male              False                      False
# 39               male              False                      False
#
#    season_name               match_updated           match_updated_360
# 21   2020/2021  2022-12-05T14:39:07.366723  2023-04-14T11:06:45.699840  \
# 22   2019/2020  2023-02-25T12:34:02.427349     2021-06-13T16:17:31.694
# 23   2018/2019  2023-04-14T08:32:25.407577  2021-07-09T14:53:22.103024
# 24   2017/2018  2023-04-07T05:26:33.303597     2021-06-13T16:17:31.694
# 25   2016/2017  2022-11-30T18:35:52.394297     2021-06-13T16:17:31.694
# 26   2015/2016  2023-02-21T15:55:07.071365     2021-06-13T16:17:31.694
# 27   2014/2015  2022-08-14T18:49:03.341489     2021-06-13T16:17:31.694
# 28   2013/2014  2022-07-23T12:18:49.547396     2021-06-13T16:17:31.694
# 29   2012/2013  2022-09-25T20:52:24.444609     2021-06-13T16:17:31.694
# 30   2011/2012  2022-12-01T14:10:17.791769     2021-06-13T16:17:31.694
# 31   2010/2011  2022-11-30T15:40:53.042701     2021-06-13T16:17:31.694
# 32   2009/2010  2021-10-26T13:56:40.989214     2021-06-13T16:17:31.694
# 33   2008/2009            2020-07-29T05:00     2021-06-13T16:17:31.694
# 34   2007/2008  2021-10-26T13:13:56.180589     2021-06-13T16:17:31.694
# 35   2006/2007  2023-03-26T23:19:39.125951     2021-06-13T16:17:31.694
# 36   2005/2006  2022-07-03T12:34:31.749038     2021-06-13T16:17:31.694
# 37   2004/2005            2020-07-29T05:00     2021-06-13T16:17:31.694
# 39   2003/2004  2023-03-11T10:52:12.579230     2021-06-13T16:17:31.694
#
#            match_available_360             match_available
# 21  2023-04-14T11:06:45.699840  2022-12-05T14:39:07.366723
# 22                        None  2023-02-25T12:34:02.427349
# 23                        None  2023-04-14T08:32:25.407577
# 24                        None  2023-04-07T05:26:33.303597
# 25                        None  2022-11-30T18:35:52.394297
# 26                        None  2023-02-21T15:55:07.071365
# 27                        None  2022-08-14T18:49:03.341489
# 28                        None  2022-07-23T12:18:49.547396
# 29                        None  2022-09-25T20:52:24.444609
# 30                        None  2022-12-01T14:10:17.791769
# 31                        None  2022-11-30T15:40:53.042701
# 32                        None  2021-10-26T13:56:40.989214
# 33                        None            2020-07-29T05:00
# 34                        None  2021-10-26T13:13:56.180589
# 35                        None  2023-03-26T23:19:39.125951
# 36                        None  2022-07-03T12:34:31.749038
# 37                        None            2020-07-29T05:00
# 39                        None  2023-03-11T10:52:12.579230

# %% [markdown]
# > **Note**: Scratch my EPL La Liga comparison.  There is only one season of EPL games in 2003/2004.  La Liga looks healthy enough.

# %% [markdown]
# ### Match Data
# To select match data, you must select a competitiion and a season.  This is done with the .match() method specifying the attributes previously identified.  This will still not provide event data, but we must crawl, walk, and then run.

# %%
# df_matches = parser.match(competition_id=72, season_id=30)

# %% [markdown]
# ### Library Issue, shift to statsbombpy
# The mplsoccer library call to the Statsbomb API is not working.  There seems to be an error with the dateformating process which is impacts the code execution.  Pivoting to the statsbomb API directly to ascertain if the data can be pulled directly.  First I need to install the libarary, the import it into this notebook.

# %%
from statsbombpy import sb

# %%
# suppress due to free data warning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Competitions data

# %%
sb.competitions(creds={'user': None, 'passwd': None}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   competition_id             43 non-null     int64
#  1   season_id                  43 non-null     int64
#  2   country_name               43 non-null     object
#  3   competition_name           43 non-null     object
#  4   competition_gender         43 non-null     object
#  5   competition_youth          43 non-null     bool
#  6   competition_international  43 non-null     bool
#  7   season_name                43 non-null     object
#  8   match_updated              43 non-null     object
#  9   match_updated_360          42 non-null     object
#  10  match_available_360        4 non-null      object
#  11  match_available            43 non-null     object
# dtypes: bool(2), int64(2), object(8)
# memory usage: 3.6+ KB

# %%
sb.competitions(creds={'user': None, 'passwd': None})
# Out:
#     competition_id  season_id              country_name
# 0               16          4                    Europe  \
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         90                   England
# 16              37         42                   England
# 17              37          4                   England
# 18              43        106             International
# 19              43          3             International
# 20            1238        108                     India
# 21              11         90                     Spain
# 22              11         42                     Spain
# 23              11          4                     Spain
# 24              11          1                     Spain
# 25              11          2                     Spain
# 26              11         27                     Spain
# 27              11         26                     Spain
# 28              11         25                     Spain
# 29              11         24                     Spain
# 30              11         23                     Spain
# 31              11         22                     Spain
# 32              11         21                     Spain
# 33              11         41                     Spain
# 34              11         40                     Spain
# 35              11         39                     Spain
# 36              11         38                     Spain
# 37              11         37                     Spain
# 38              49          3  United States of America
# 39               2         44                   England
# 40              55         43                    Europe
# 41              53        106                    Europe
# 42              72         30             International
#
#            competition_name competition_gender  competition_youth
# 0          Champions League               male              False  \
# 1          Champions League               male              False
# 2          Champions League               male              False
# 3          Champions League               male              False
# 4          Champions League               male              False
# 5          Champions League               male              False
# 6          Champions League               male              False
# 7          Champions League               male              False
# 8          Champions League               male              False
# 9          Champions League               male              False
# 10         Champions League               male              False
# 11         Champions League               male              False
# 12         Champions League               male              False
# 13         Champions League               male              False
# 14         Champions League               male              False
# 15  FA Women's Super League             female              False
# 16  FA Women's Super League             female              False
# 17  FA Women's Super League             female              False
# 18           FIFA World Cup               male              False
# 19           FIFA World Cup               male              False
# 20      Indian Super league               male              False
# 21                  La Liga               male              False
# 22                  La Liga               male              False
# 23                  La Liga               male              False
# 24                  La Liga               male              False
# 25                  La Liga               male              False
# 26                  La Liga               male              False
# 27                  La Liga               male              False
# 28                  La Liga               male              False
# 29                  La Liga               male              False
# 30                  La Liga               male              False
# 31                  La Liga               male              False
# 32                  La Liga               male              False
# 33                  La Liga               male              False
# 34                  La Liga               male              False
# 35                  La Liga               male              False
# 36                  La Liga               male              False
# 37                  La Liga               male              False
# 38                     NWSL             female              False
# 39           Premier League               male              False
# 40                UEFA Euro               male              False
# 41        UEFA Women's Euro             female              False
# 42        Women's World Cup             female              False
#
#     competition_international season_name               match_updated
# 0                       False   2018/2019  2023-03-07T12:20:48.118250  \
# 1                       False   2017/2018  2021-08-27T11:26:39.802832
# 2                       False   2016/2017  2021-08-27T11:26:39.802832
# 3                       False   2015/2016  2021-08-27T11:26:39.802832
# 4                       False   2014/2015  2021-08-27T11:26:39.802832
# 5                       False   2013/2014  2021-08-27T11:26:39.802832
# 6                       False   2012/2013  2021-08-27T11:26:39.802832
# 7                       False   2011/2012  2021-08-27T11:26:39.802832
# 8                       False   2010/2011  2022-01-26T21:07:11.033473
# 19         Barcelona            Huesca           4           1    available
# 20         Barcelona            Getafe           5           2    available
# 21     Real Sociedad         Barcelona           1           6    available
# 22         Barcelona     Real Sociedad           2           1    available
# 23   Real Valladolid         Barcelona           0           3    available
# 24             Cádiz         Barcelona           2           1    available
# 25     Athletic Club         Barcelona           2           3    available
# 26         Barcelona  Deportivo Alavés           5           1    available
# 27         Barcelona   Real Valladolid           1           0    available
# 28           Sevilla         Barcelona           0           2    available
# 29         Barcelona     Athletic Club           2           1    available
# 30         Barcelona           Osasuna           4           0    available
# 31         Barcelona             Cádiz           1           1    available
# 32         Barcelona             Elche           3           0    available
# 33        Villarreal         Barcelona           1           2    available
# 34         Barcelona        Real Betis           5           2    available
#
#     ...            last_updated_360 match_week competition_stage
# 0   ...            2022-08-04T12:00         37    Regular Season  \
# 1   ...            2022-08-04T12:00         22    Regular Season
# 2   ...            2022-08-04T12:00         26    Regular Season
# 3   ...            2022-08-04T12:00         30    Regular Season
# 4   ...            2022-08-04T12:00         13    Regular Season
# 5   ...            2022-08-04T12:00          3    Regular Season
# 6   ...            2022-08-04T12:00          4    Regular Season
# 7   ...            2022-08-04T12:00          7    Regular Season
# 8   ...            2022-08-04T12:00         17    Regular Season
# 9   ...            2022-08-04T12:00          5    Regular Season
# 10  ...            2022-08-04T12:00          8    Regular Season
# 11  ...            2022-08-04T12:00         18    Regular Season
# 12  ...            2022-08-04T12:00          6    Regular Season
# 13  ...            2022-08-04T12:00         10    Regular Season
# 14  ...            2022-08-04T12:00         14    Regular Season
# 15  ...            2022-08-04T12:00         33    Regular Season
# 16  ...            2022-08-04T12:00         35    Regular Season
# 17  ...            2022-08-04T12:00         36    Regular Season
# 18  ...            2022-08-04T12:00         34    Regular Season
# 19  ...            2022-08-04T12:00         27    Regular Season
# 20  ...            2022-08-04T12:00         31    Regular Season
# 21  ...            2022-08-04T12:00         28    Regular Season
# 22  ...            2022-08-04T12:00         19    Regular Season
# 23  ...            2022-08-04T12:00         15    Regular Season
# 24  ...  2022-08-16T16:58:56.393344         12    Regular Season
# 25  ...            2022-08-04T12:00          2    Regular Season
# 26  ...            2022-08-04T12:00         23    Regular Season
# 27  ...            2022-08-04T12:00         29    Regular Season
# 28  ...            2022-08-04T12:00         25    Regular Season
# 29  ...            2022-08-04T12:00         21    Regular Season
# 30  ...            2022-08-04T12:00         11    Regular Season
# 31  ...            2022-08-04T12:00         24    Regular Season
# 32  ...            2022-08-04T12:00          1    Regular Season
# 33  ...            2022-08-04T12:00         32    Regular Season
# 34  ...            2022-08-04T12:00          9    Regular Season
#
#                             stadium                             referee
# 0                  Spotify Camp Nou                                 NaN  \
# 1         Estadio Benito Villamarín                                 NaN
# 2                  Estadio El Sadar          Guillermo Cuadra Fernández
# 3        Estadio Alfredo Di Stéfano                   Jesús Gil Manzano
# 4                  Spotify Camp Nou        Ricardo De Burgos Bengoetxea
# 5                  Spotify Camp Nou          Guillermo Cuadra Fernández
# 6                   Abanca-Balaídos             Carlos del Cerro Grande
# 7                  Spotify Camp Nou               Juan Martínez Munuera
# 27                     Ronald Koeman           Sergio González Soriano
# 28            Julen Lopetegui Argote                     Ronald Koeman
# 29                     Ronald Koeman            Marcelino García Toral
# 30                     Ronald Koeman         Jagoba Arrasate Elustondo
# 31                     Ronald Koeman               Álvaro Cervera Díaz
# 32                     Ronald Koeman          Francisco Escriba Segura
# 33              Unai Emery Etxegoien                     Ronald Koeman
# 34                     Ronald Koeman  Manuel Luis Pellegrini Ripamonti
#
#    data_version shot_fidelity_version xy_fidelity_version
# 0         1.1.0                     2                   2
# 1         1.1.0                     2                   2
# 2         1.1.0                     2                   2
# 3         1.1.0                     2                   2
# 4         1.1.0                     2                   2
# 5         1.1.0                     2                   2
# 6         1.1.0                     2                   2
# 7         1.1.0                     2                   2
# 8         1.1.0                     2                   2
# 9         1.1.0                     2                   2
# 10        1.1.0                     2                   2
# 11        1.1.0                     2                   2
# 12        1.1.0                     2                   2
# 13        1.1.0                     2                   2
# 14        1.1.0                     2                   2
# 15        1.1.0                     2                   2
# 16        1.1.0                     2                   2
# 17        1.1.0                     2                   2
# 18        1.1.0                     2                   2
# 19        1.1.0                     2                   2
# 20        1.1.0                     2                   2
# 21        1.1.0                     2                   2
# 22        1.1.0                     2                   2
# 23        1.1.0                     2                   2
# 24        1.1.0                     2                   2
# 25        1.1.0                     2                   2
# 26        1.1.0                     2                   2
# 27        1.1.0                     2                   2
# 28        1.1.0                     2                   2
# 29        1.1.0                     2                   2
# 30        1.1.0                     2                   2
# 31        1.1.0                     2                   2
# 32        1.1.0                     2                   2
# 33        1.1.0                     2                   2
# 34        1.1.0                     2                   2
#
# [35 rows x 22 columns]

# %% [markdown]
# #### Event data within Matches
# This is where things get more interesting.  There is excessive amounts of information at this level.  The data can be extracted into a default dict storing multiple independent dataframes.  This is helpful if you want the data parsed at a lower level to minimize the dataoverload.

# %%
sb.events(match_id=3773457).type.value_counts()
# Out:
# type
# Pass                 1201
# Ball Receipt*        1153
# Carry                 916
# Pressure              411
# Ball Recovery          79
# Duel                   67
# Dribble                43
# Block                  38
# Dispossessed           37
# Clearance              34
# Foul Committed         34
# Foul Won               33
# Dribbled Past          31
# Goal Keeper            30
# Interception           29
# Shot                   25
# Miscontrol             20
# Substitution            8
# Half Start              4
# Half End                4
# Injury Stoppage         2
# Referee Ball-Drop       2
# Starting XI             2
# Shield                  1
# Tactical Shift          1
# Name: count, dtype: int64

# %% [markdown]
# ### Distinct event type dataframes
# Here, the data is split using the split parameter, and setting it to True.  This provides a dictionary to leverage different event type keys allows inspection of specific types of occurances.

# %%
# Multiple event types can be split out versus provided in a single frame

sb.events(match_id=3773457, split=True, flatten_attrs=False).keys() # Dictionary format, access dfs with keys
# Out:
# dict_keys(['starting_xis', 'half_starts', 'passes', 'ball_receipts', 'carrys', 'pressures', 'interceptions', 'dispossesseds', 'duels', 'miscontrols', 'ball_recoverys', 'dribbled_pasts', 'dribbles', 'clearances', 'shots', 'goal_keepers', 'blocks', 'foul_committeds', 'foul_wons', 'shields', 'half_ends', 'substitutions', 'injury_stoppages', 'referee_ball_drops', 'tactical_shifts'])

# %%
# Passing data extracted from overall view, 1201 passsing records in the fixture

sb.events(match_id=3773457, split=True, flatten_attrs=False)['passes'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1201 entries, 0 to 1200
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  1201 non-null   object
#  1   index               1201 non-null   int64
#  2   period              1201 non-null   int64
#  3   timestamp           1201 non-null   object
#  4   minute              1201 non-null   int64
#  5   second              1201 non-null   int64
#  6   type                1201 non-null   object
#  7   possession          1201 non-null   int64
#  8   possession_team     1201 non-null   object
#  9   play_pattern        1201 non-null   object
#  10  team                1201 non-null   object
#  11  player              1201 non-null   object
#  12  position            1201 non-null   object
#  13  location            1201 non-null   object
#  14  duration            1201 non-null   float64
#  15  related_events      1192 non-null   object
#  16  pass                1201 non-null   object
#  17  match_id            1201 non-null   int64
#  18  possession_team_id  1201 non-null   int64
#  19  team_id             1201 non-null   int64
#  20  player_id           1201 non-null   int64
#  21  under_pressure      210 non-null    object
#  22  counterpress        12 non-null     object
#  23  off_camera          57 non-null     object
# dtypes: float64(1), int64(9), object(14)
# memory usage: 225.3+ KB

# %% [markdown]
# ### Competition Events
# All events from a single competition can be queried using the .compeition_events() method.  This allows an entire seasons to be pulled at once, which is very useful when you concerned with larger macro level trends the in the game.  This will be a lot of rows.  Call below is 1M entries.
#
# >**Note**: You can also split the call to obtain grouped events as shown in the individual matches.

# %%
sb.competition_events(
    country="Spain",
    division= "La Liga",
    season="2019/2020",
    gender="male"
).head()
# Out:
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#   50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive
# 0   NaN                NaN                  NaN                     NaN  \
# 1   NaN                NaN                  NaN                     NaN
# 2   NaN                NaN                  NaN                     NaN
# 3   NaN                NaN                  NaN                     NaN
# 4   NaN                NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure block_deflection block_offensive
# 0                            NaN              NaN             NaN  \
# 1                            NaN              NaN             NaN
# 2                            NaN              NaN             NaN
# 3                            NaN              NaN             NaN
# 4                            NaN              NaN             NaN
#
#   block_save_block carry_end_location clearance_aerial_won  ...
# 0              NaN                NaN                  NaN  ...  \
# 1              NaN                NaN                  NaN  ...
# 2              NaN                NaN                  NaN  ...
# 3              NaN                NaN                  NaN  ...
# 4              NaN                NaN                  NaN  ...
#
#   shot_technique shot_type substitution_outcome substitution_replacement
# 0            NaN       NaN                  NaN                      NaN  \
# 1            NaN       NaN                  NaN                      NaN
# 2            NaN       NaN                  NaN                      NaN
# 3            NaN       NaN                  NaN                      NaN
# 4            NaN       NaN                  NaN                      NaN
#
#                                              tactics        team team_id
# 0  {'formation': 433, 'lineup': [{'player': {'id'...   Barcelona     217  \
# 1  {'formation': 4231, 'lineup': [{'player': {'id...       Eibar     322
# 2  {'formation': 433, 'lineup': [{'player': {'id'...   Barcelona     217
# 3  {'formation': 352, 'lineup': [{'player': {'id'...     Leganés     205
# 4  {'formation': 352, 'lineup': [{'player': {'id'...  Celta Vigo     209
#
#       timestamp         type under_pressure
# 0  00:00:00.000  Starting XI            NaN
# 1  00:00:00.000  Starting XI            NaN
# 2  00:00:00.000  Starting XI            NaN
# 3  00:00:00.000  Starting XI            NaN
# 4  00:00:00.000  Starting XI            NaN
#
# [5 rows x 109 columns]

# %%
laliga_20and21_events = sb.competition_events(
    country="Spain",
    division= "La Liga",
    season="2020/2021",
    gender="male",
    split=True
)
# Out:
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
# apparently the data is not complete for La Liga
(laliga_20and21_events['starting_xis']
#  .groupby(by=['team'])
 .team
 .value_counts()
#  .unstack()
)
# Out:
# team
# Barcelona           35
# Granada              2
# Athletic Club        2
# Cádiz                2
# Real Valladolid      2
# Real Sociedad        2
# Valencia             2
# Atlético Madrid      2
# Getafe               2
# Deportivo Alavés     2
# Celta Vigo           2
# Sevilla              2
# Huesca               2
# Villarreal           2
# Levante              2
# Real Madrid          2
# Osasuna              2
# Real Betis           2
# Elche                1
# Name: count, dtype: int64

# %%
WC_2022 = sb.competition_events(
    country="International",
    division= "FIFA World Cup",
    season="2022",
    gender="male",
    split=True
)
# Out:
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %% [markdown]
# ### Check for completeness
# Competition data sometimes only has partial datasets.  In the case of the 2022 World Cup, there is a record for every game seemingly available through the statsbomb dataset.

# %%
(WC_2022['starting_xis']
 .assign(formation = lambda df: [d.get('formation') for d in df.tactics])
 .formation
 .value_counts()
#  tactics.iloc[0]['formation']
#  .value_counts()
)
# Out:
# formation
# 433      36
# 4231     32
# 442      17
# 352      11
# 343       8
# 3421      7
# 3412      6
# 4141      6
# 4411      4
# 41212     1
# Name: count, dtype: int64

# %%
(WC_2022['shots']
 .groupby(['team'])
 .shot_outcome
 .value_counts()
 .unstack()
 .assign(tot = lambda df: df.sum(axis=1))
 .sort_values(by='tot', ascending=False)
#  tactics.iloc[0]['formation']
#  .value_counts()
)
# Out:
# shot_outcome   Blocked  Goal  Off T  Post  Saved  Saved Off Target
# team
# Argentina         18.0  23.0   30.0   1.0   33.0               NaN  \
# France            32.0  18.0   27.0   1.0   20.0               NaN
# Brazil            21.0  10.0   22.0   3.0   36.0               NaN
# Croatia           19.0  15.0   31.0   1.0   18.0               NaN
# Germany           14.0   6.0   21.0   5.0   18.0               NaN
# Portugal          19.0  12.0   15.0   2.0   14.0               NaN
# Morocco           16.0   9.0   24.0   NaN   11.0               1.0
# England           13.0  13.0   17.0   3.0   15.0               NaN
# Spain             14.0   9.0   15.0   2.0    9.0               NaN
# Senegal           14.0   5.0   21.0   NaN    7.0               NaN
# Japan             16.0   6.0   10.0   NaN   12.0               NaN
# South Korea       15.0   5.0   12.0   NaN   13.0               NaN
# Netherlands       10.0  13.0   16.0   1.0    8.0               NaN
# United States     13.0   3.0   13.0   2.0   10.0               NaN
# Mexico            13.0   2.0   11.0   NaN   13.0               NaN
# Switzerland       13.0   5.0    9.0   NaN    8.0               NaN
# Belgium           11.0   1.0   11.0   1.0    9.0               NaN
# Denmark            9.0   1.0   10.0   2.0   10.0               NaN
# Canada            12.0   1.0   17.0   1.0    4.0               NaN
# Iran              11.0   4.0    9.0   2.0    5.0               NaN
# Uruguay            4.0   2.0   14.0   3.0    8.0               NaN
# Serbia             6.0   5.0   13.0   2.0    4.0               NaN
# Tunisia           13.0   1.0   10.0   NaN    7.0               NaN
# Poland            12.0   3.0    5.0   2.0    4.0               NaN
# Ecuador            8.0   4.0    6.0   1.0    7.0               NaN
# Saudi Arabia       5.0   3.0   15.0   NaN    6.0               NaN
# Cameroon           5.0   4.0    6.0   NaN   12.0               NaN
# Australia          9.0   3.0    6.0   1.0    5.0               NaN
# Ghana              3.0   5.0   11.0   NaN    5.0               NaN
# Wales              6.0   1.0    8.0   NaN    6.0               1.0
# Qatar              3.0   1.0   11.0   NaN    5.0               NaN
# Costa Rica         2.0   2.0    2.0   NaN    4.0               NaN
#
# shot_outcome   Saved to Post  Wayward    tot
# team
# Argentina                NaN      5.0  110.0
# France                   NaN      8.0  106.0
# Brazil                   NaN      7.0   99.0
# Croatia                  NaN      3.0   87.0
# Germany                  NaN      4.0   68.0
# Portugal                 NaN      4.0   66.0
# Morocco                  1.0      4.0   66.0
# England                  NaN      2.0   63.0
# Spain                    1.0      1.0   51.0
# Senegal                  NaN      3.0   50.0
# Japan                    NaN      4.0   48.0
# South Korea              NaN      3.0   48.0
# Netherlands              NaN      NaN   48.0
# United States            NaN      5.0   46.0
# Mexico                   NaN      2.0   41.0
# Switzerland              NaN      2.0   37.0
# Belgium                  NaN      2.0   35.0
# Denmark                  NaN      3.0   35.0
# Canada                   NaN      NaN   35.0
# Iran                     1.0      1.0   33.0
# Uruguay                  NaN      2.0   33.0
# Serbia                   NaN      2.0   32.0
# Tunisia                  NaN      1.0   32.0
# Poland                   NaN      5.0   31.0
# Ecuador                  NaN      4.0   30.0
# Saudi Arabia             NaN      1.0   30.0
# Cameroon                 NaN      1.0   28.0
# Australia                NaN      2.0   26.0
# Ghana                    NaN      1.0   25.0
# Wales                    NaN      2.0   24.0
# Qatar                    NaN      NaN   20.0
# Costa Rica               NaN      1.0   11.0

# %% [markdown]
# ### 360 data
# If there is 360 data avaialble, you can access the data with the include_360_metrics=True flag.  This is typically a paywall dataset, so we may not get much in terms of access for the course.

# %%
try:
    WC_2022_360 = sb.competition_events(
    country="International",
    division= "FIFA World Cup",
    season="2022",
    gender="male",
    split=True,
    include_360_metrics=True
    )
except:
    print('not available in open data')
# Out:
# not available in open data
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/keithnhoffman/Python_projs/footy_analytics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
